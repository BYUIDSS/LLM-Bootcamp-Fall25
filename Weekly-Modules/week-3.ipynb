# %% [markdown]
# # Week 3 - LLM Bootcamp
#
# ## Objectives
#
# - Run a simple agent
# - Connect agents to function calls
# - Define MCP and connect to a server
# - Enable an agent to browse the internet
