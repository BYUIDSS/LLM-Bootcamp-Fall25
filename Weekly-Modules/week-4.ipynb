# %% [markdown]
# # Week 4 - Diagnostics
#
# ## Objectives
#
# - Use diagnostic systems to evaluate and monitor LLM performance.

# %% [markdown]
# ## Lecture
#
# [Week content to be added]

# %% [markdown]
# # LangSmith: Get Started
#
# Get this set up
#
# https://docs.langchain.com/langsmith/home

# %% [markdown]
# # Explore
#
# Try attaching to existing workflows and agents made
#
# Use the chat interface in LangSmith
#
# Go through a tutorial
